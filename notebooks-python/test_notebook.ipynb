# %%
from pprint import pprint
import mudata as md
import anndata as ad

# %%
data_file_path = "data/Project_Brand_Perkins_copy.h5mu"

# %%
mudata = md.read(data_file_path)
# Out:
# C:\Python311\Lib\site-packages\mudata\_core\mudata.py:491: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(

# %%
pprint(mudata)
# Out:
# MuData object with n_obs × n_vars = 60043 × 23678
#   3 modalities
#     rna:	60043 x 19548
#       obs:	'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'Batch', 'S_score', 'G2M_score', 'phase'
#       obsm:	'X_draw_graph_fa', 'protein_expression'
#     rna_subset:	60043 x 4000
#       obs:	'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', '_scvi_labels', '_scvi_batch', 'none', 'leiden_totalVI', 'Annotation', 'color', 'dpt_pseudotime', 'majority_voting', 'phase', 'Batch'
#       var:	'highly_variable-1', 'highly_variable_rank-1', 'means-1', 'variances-1', 'variances_norm-1', 'highly_variable_nbatches-1'
# ...

# %%
mudata.shape
# Out:
# (60043, 23678)

# %%
mudata.n_obs
# Out:
# 60043

# %%
mudata.n_vars
# Out:
# 23678

# %%
print(mudata["rna"])
# Out:
# AnnData object with n_obs × n_vars = 60043 × 19548
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'Batch', 'S_score', 'G2M_score', 'phase'
#     obsm: 'X_draw_graph_fa', 'protein_expression'

# %%
print(mudata["rna_subset"])
# Out:
# AnnData object with n_obs × n_vars = 60043 × 4000
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', '_scvi_labels', '_scvi_batch', 'none', 'leiden_totalVI', 'Annotation', 'color', 'dpt_pseudotime', 'majority_voting', 'phase', 'Batch'
#     var: 'highly_variable-1', 'highly_variable_rank-1', 'means-1', 'variances-1', 'variances_norm-1', 'highly_variable_nbatches-1'
#     uns: 'Anno_level_fig1_colors', 'Annotation_colors', 'Sample_colors', '_scvi_manager_uuid', '_scvi_uuid', 'batch_colors', 'color_colors', 'diffmap_evals', 'draw_graph', 'iroot', 'leiden', 'leiden_totalVI_colors', 'leiden_totalVI_sizes', 'majority_voting_colors', 'majority_voting_sizes', 'neighbors', 'paga', 'umap'
#     obsm: 'X_diffmap', 'X_draw_graph_fa', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
print(mudata["protein"])
# Out:
# AnnData object with n_obs × n_vars = 60043 × 130
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', '_scvi_labels', '_scvi_batch', 'none', 'leiden_totalVI', 'Annotation', 'color', 'dpt_pseudotime', 'majority_voting', 'phase', 'Batch'
#     obsm: 'X_draw_graph_fa'

# %%
# md.write("data/rna_data.h5mu", mudata["rna"])
# mudata["rna_subset"].write("data/rna_data.h5mu")

# %%
category_counts = mudata["rna"].obs["Batch"].value_counts().reset_index()
category_counts.columns = ["Batch", "Count"]
category_counts
# Out:
#    Batch  Count
# 0  ATLAS  40848
# 1    PB2   6517
# 2    BM4   5595
# 3    TH1   4373
# 4    TH2   2710

# %%
set(mudata["rna"].obs["Batch"])
# Out:
# {'ATLAS', 'BM4', 'PB2', 'TH1', 'TH2'}

# %%
mudata["rna"].to_df()
# Out:
# index                                         TSPAN6  TNMD      DPM1  \
# TTA13-ATCACGAAGAGAACAG_ATLAS                     0.0   0.0  3.851911
# FCAImmP7579219-GAACGGACACGACGAA_ATLAS            0.0   0.0  0.000000
# T06_TH_TOT_5GEX_2_S10-CTGATAGCATTACCTT_ATLAS     0.0   0.0  0.000000
# TTA9-CTTCTCTCAGGGTACA_ATLAS                      0.0   0.0  0.000000
# 4861STDY7528585-GCGCAGTTCTCGCTTG_ATLAS           0.0   0.0  0.000000
# ...                                              ...   ...       ...
# TTTGTTGAGGGCAATC-1_PB2                           0.0   0.0  0.000000
# TTTGTTGCAGCGACCT-1_PB2                           0.0   0.0  2.820950
# TTTGTTGCATTGAAAG-1_PB2                           0.0   0.0  0.000000
# TTTGTTGGTGCTCTCT-1_PB2                           0.0   0.0  0.000000
# TTTGTTGGTTCGGTCG-1_PB2                           0.0   0.0  0.000000
#
# index                                            SCYL3  C1orf112      FGR  \
# ...

# %%
len(mudata["rna"].to_df().columns)
# Out:
# 19548

# %%
len(set(mudata["rna"].to_df().columns))
# Out:
# 19548

# %%
mudata["rna_subset"].to_df()
# Out:
# index                                             FGR    ANKIB1      CD99  \
# TTA13-ATCACGAAGAGAACAG_ATLAS                  0.00000  0.000000  5.089387
# FCAImmP7579219-GAACGGACACGACGAA_ATLAS         0.00000  0.000000  6.145041
# T06_TH_TOT_5GEX_2_S10-CTGATAGCATTACCTT_ATLAS  0.00000  0.000000  5.351958
# TTA9-CTTCTCTCAGGGTACA_ATLAS                   0.00000  0.000000  5.410382
# 4861STDY7528585-GCGCAGTTCTCGCTTG_ATLAS        0.00000  0.000000  0.000000
# ...                                               ...       ...       ...
# TTTGTTGAGGGCAATC-1_PB2                        0.00000  3.134748  3.134748
# TTTGTTGCAGCGACCT-1_PB2                        2.82095  3.483870  2.820950
# TTTGTTGCATTGAAAG-1_PB2                        0.00000  3.607344  0.000000
# TTTGTTGGTGCTCTCT-1_PB2                        0.00000  2.143138  2.775852
# TTTGTTGGTTCGGTCG-1_PB2                        0.00000  0.000000  4.032091
#
# index                                         HS3ST1  TMEM176A  KLHL13  \
# ...

# %%
mudata["protein"].to_df()
# Out:
#                                               ADT.anti.hu.CD86  \
# TTA13-ATCACGAAGAGAACAG_ATLAS                          0.096086
# FCAImmP7579219-GAACGGACACGACGAA_ATLAS                 0.049426
# T06_TH_TOT_5GEX_2_S10-CTGATAGCATTACCTT_ATLAS          0.089743
# TTA9-CTTCTCTCAGGGTACA_ATLAS                           0.071345
# 4861STDY7528585-GCGCAGTTCTCGCTTG_ATLAS                0.142394
# ...                                                        ...
# TTTGTTGAGGGCAATC-1_PB2                                0.000044
# TTTGTTGCAGCGACCT-1_PB2                                0.000573
# TTTGTTGCATTGAAAG-1_PB2                                0.000150
# TTTGTTGGTGCTCTCT-1_PB2                                0.000086
# TTTGTTGGTTCGGTCG-1_PB2                                0.000059
#
#                                               ADT.anti.hu.CD274..B7.H1.PD.L1.  \
# TTA13-ATCACGAAGAGAACAG_ATLAS                                         2.219621
# ...

# %%
mudata["protein"].write_h5ad("test_output2.h5ad")

# %%
# %pip install anndata2ri
# Out:
# ...
#      ---------------------------------------- 0.0/219.3 kB ? eta -:--:--
#      -------------------------------------- 219.3/219.3 kB 6.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [40 lines of output]
#   test_pw_r.c
#   LINK : fatal error LNK1181: cannot open input file 'R.lib'
#   Traceback (most recent call last):
#     File "C:\Users\satra\AppData\Local\Temp\pip-build-env-01updhyd\overlay\Lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 508, in link
#       self.spawn([self.linker] + ld_args)
# ...
